# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn import preprocessing

# %%
df = pd.read_csv('uber.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.tail()
# Out:
#         Unnamed: 0                           key  fare_amount  \
# 199995    42598914  2012-10-28 10:49:00.00000053          3.0
# 199996    16382965   2014-03-14 01:09:00.0000008          7.5
# 199997    27804658  2009-06-29 00:42:00.00000078         30.9
# 199998    20259894   2015-05-20 14:56:25.0000004         14.5
# 199999    11951496  2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df.shape
# Out:
# (200000, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0', 'key'], axis=1)

# %%
df.shape
# Out:
# (200000, 7)

# %%
df.isna().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce')

# %%
df['second'] = df['pickup_datetime'].dt.second
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1               7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2              12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3               5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4              16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...             ...                       ...               ...
# 199995          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.738354         -73.999512         40.723217                1
# 1             40.728225         -73.994710         40.750325                1
# 2             40.740770         -73.962565         40.772647                1
# 3             40.790844         -73.965316         40.803349                3
# 4             40.744085         -73.973082         40.761247                5
# ...                 ...                ...               ...              ...
# 199995        40.739367         -73.986525         40.740297                1
# 199996        40.736837         -74.006672         40.739620                1
# 199997        40.756487         -73.858957         40.692588                2
# 199998        40.725452         -73.983215         40.695415                1
# 199999        40.720077         -73.985508         40.768793                1
#
#         second
# 0            6
# 1           56
# 2            0
# 3           21
# 4            0
# ...        ...
# 199995       0
# 199996       0
# 199997       0
# 199998      25
# 199999       0
#
# [199999 rows x 8 columns]

# %%
df['minute'] = df['pickup_datetime'].dt.minute
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1               7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2              12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3               5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4              16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...             ...                       ...               ...
# 199995          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 
are_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek
# 0          3
# 1          4
# 2          0
# 3          4
# 4          3

# %%
incorrect_coordinates = df.loc[
    (df.pickup_latitude > 90) |(df.pickup_latitude < -90) |
    (df.dropoff_latitude > 90) |(df.dropoff_latitude < -90) |
    (df.pickup_longitude > 180) |(df.pickup_longitude < -180) |
    (df.dropoff_longitude > 90) |(df.dropoff_longitude < -90)
]

df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')

# %%
df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               7.5        -73.999817        40.738354         -73.999512
# 1               7.7        -73.994355        40.728225         -73.994710
# 2              12.9        -74.005043        40.740770         -73.962565
# 3               5.3        -73.976124        40.790844         -73.965316
# 4              16.0        -73.925023        40.744085         -73.973082
# ...             ...               ...              ...                ...
# 199995          3.0        -73.987042        40.739367         -73.986525
# 199996          7.5        -73.984722        40.736837         -74.006672
# 199997         30.9        -73.986017        40.756487         -73.858957
# 199998         14.5        -73.997124        40.725452         -73.983215
# 199999         14.1        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count  second  minute  hour  day  month  \
# 0              40.723217                1       6      52    19    7      5
# 1              40.750325                1      56       4    20   17      7
# 2              40.772647                1       0      45    21   24      8
# 3              40.803349                3      21      22     8   26      6
# 4              40.761247                5       0      47    17   28      8
# ...                  ...              ...     ...     ...   ...  ...    ...
# 199995         40.740297                1       0      49    10   28     10
# 199996         40.739620                1       0       9     1   14      3
# 199997         40.692588                2       0      42     0   29      6
# 199998         40.695415                1      25      56    14   20      5
# 199999         40.768793                1       0       8     4   15      5
#
#         year  dayofweek
# 0       2015          3
# 1       2009          4
# 2       2009          0
# 3       2009          4
# 4       2014          3
# ...      ...        ...
# 199995  2012          6
# 199996  2014          4
# 199997  2009          0
# 199998  2015          2
# 199999  2010          5
#
# [199999 rows x 13 columns]

# %%
def distance_transform(longitude1, latitude1, longitude2, latitude2):
    long1, lati1, long2, lati2 = map(np.radians, [longitude1, latitude1, longitude2, latitude2])
    dist_long = long2 - long1
    dist_lati = lati2 - lati1
    a = np.sin(dist_lati/2)**2 + np.cos(lati1) * np.cos(lati2) * np.sin(dist_long/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) * 6371
    # long1,lati1,long2,lati2 = longitude1[pos],latitude1[pos],longitude2[pos],latitude2[pos]
    # c = sqrt((long2 - long1) ** 2 + (lati2 - lati1) ** 2)asin 
       
    return c

# %%
df['Distance'] = distance_transform(
    df['pickup_longitude'],
    df['pickup_latitude'],
    df['dropoff_longitude'],
    df['dropoff_latitude']
)

# %%
df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0
# 75%        19.000000      23.000000       9.000000    2013.000000
# max        23.000000      31.000000      12.000000    2015.000000
#
#            dayofweek       Distance
# count  199999.000000  199999.000000
# mean        3.048435      20.855350
# std         1.946946     382.964642
# min         0.000000       0.000000
# 25%         1.000000       1.215222
# 50%         3.000000       2.120992
# 75%         5.000000       3.875169
# max         6.000000   16409.239135

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
plt.figure(figsize=(20,12))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
df.drop(df[df['Distance'] >= 60].index, inplace = True)
df.drop(df[df['fare_amount'] <= 0].index, inplace = True)

df.drop(df[(df['fare_amount']>100) & (df['Distance']<1)].index, inplace = True )
df.drop(df[(df['fare_amount']<100) & (df['Distance']>100)].index, inplace = True )

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
corr = df.corr()

corr.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_5d252_row0_col0, #T_5d252_row1_col1, #T_5d252_row1_col3, #T_5d252_row2_col2, #T_5d252_row3_col1, #T_5d252_row3_col3, #T_5d252_row4_col4, #T_5d252_row5_col5, #T_5d252_row6_col6, #T_5d252_row7_col7, #T_5d252_row8_col8, #T_5d252_row9_col9, #T_5d252_row10_col10, #T_5d252_row11_col11, #T_5d252_row12_col12, #T_5d252_row13_col13 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5d252_row0_col1, #T_5d252_row0_col3, #T_5d252_row7_col1, #T_5d252_row7_col3, #T_5d252_row8_col1, #T_5d252_row8_col3, #T_5d252_row9_col1, #T_5d252_row9_col3, #T_5d252_row10_col4, #T_5d252_row11_col1, #T_5d252_row11_col3, #T_5d252_row12_col1, #T_5d252_row12_col3 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_5d252_row0_col2, #T_5d252_row7_col2, #T_5d252_row9_col2, #T_5d252_row9_col4, #T_5d252_row11_col2, #T_5d252_row11_col4, #T_5d252_row12_col2 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_5d252_row0_col4, #T_5d252_row5_col1, #T_5d252_row5_col2, #T_5d252_row5_col3, #T_5d252_row5_col4, #T_5d252_row7_col4, #T_5d252_row8_col2, #T_5d252_row8_col4, #T_5d252_row10_col1, #T_5d252_row10_col2, #T_5d252_row10_col3, #T_5d252_row12_col4 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_5d252_row0_col5, #T_5d252_row6_col11, #T_5d252_row10_col5 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_5d252_row0_col6, #T_5d252_row2_col5, #T_5d252_row4_col5, #T_5d252_row9_col6 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_5d252_row0_col7, #T_5d252_row1_col2, #T_5d252_row1_col4, #T_5d252_row1_col13, #T_5d252_row3_col2, #T_5d252_row3_col4, #T_5d252_row3_col13, #T_5d252_row4_col1, #T_5d252_row4_col3, #T_5d252_row5_col6, #T_5d252_row6_col5, #T_5d252_row8_col0, #T_5d252_row8_col12, #T_5d252_row10_col9, #T_5d252_row10_col11, #T_5d252_row11_col10, #T_5d252_row12_col8, #T_5d252_row13_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_5d252_row0_col8, #T_5d252_row6_col10 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_5d252_row0_col9, #T_5d252_row6_col0, #T_5d252_row7_col9, #T_5d252_row13_col9 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_5d252_row0_col10, #T_5d252_row10_col6 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_5d252_row0_col11 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_5d252_row0_col12, #T_5d252_row1_col12, #T_5d252_row3_col12, #T_5d252_row9_col8, #T_5d252_row9_col10, #T_5d252_row9_col12, #T_5d252_row11_col12 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_5d252_row0_col13 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_5d252_row1_col0, #T_5d252_row1_col9, #T_5d252_row3_col0, #T_5d252_row3_col9, #T_5d252_row5_col9, #T_5d252_row8_col9, #T_5d252_row9_col0, #T_5d252_row12_col0, #T_5d252_row12_col9 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_5d252_row1_col5, #T_5d252_row3_col5, #T_5d252_row7_col5, #T_5d252_row7_col6, #T_5d252_row9_col5, #T_5d252_row12_col6, #T_5d252_row13_col6 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_5d252_row1_col6, #T_5d252_row3_col6, #T_5d252_row8_col6 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_5d252_row1_col7, #T_5d252_row2_col1, #T_5d252_row2_col3, #T_5d252_row2_col7, #T_5d252_row2_col9, #T_5d252_row3_col7, #T_5d252_row4_col7, #T_5d252_row4_col9, #T_5d252_row5_col7, #T_5d252_row6_col7, #T_5d252_row8_col7, #T_5d252_row9_col7, #T_5d252_row10_col7, #T_5d252_row11_col7, #T_5d252_row11_col9, #T_5d252_row12_col7 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_5d252_row1_col8, #T_5d252_row2_col8, #T_5d252_row3_col8, #T_5d252_row4_col8, #T_5d252_row6_col12, #T_5d252_row7_col8, #T_5d252_row11_col8 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_5d252_row1_col10, #T_5d252_row2_col11, #T_5d252_row3_col10, #T_5d252_row4_col11, #T_5d252_row7_col11, #T_5d252_row7_col13, #T_5d252_row8_col10, #T_5d252_row12_col10, #T_5d252_row13_col12 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_5d252_row1_col11, #T_5d252_row2_col10, #T_5d252_row3_col11, #T_5d252_row4_col10, #T_5d252_row5_col11, #T_5d252_row6_col13, #T_5d252_row7_col10, #T_5d252_row8_col11, #T_5d252_row9_col13, #T_5d252_row12_col11 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_5d252_row2_col0, #T_5d252_row4_col0, #T_5d252_row6_col9, #T_5d252_row7_col0 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_5d252_row2_col4, #T_5d252_row4_col2 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_5d252_row2_col6, #T_5d252_row4_col6, #T_5d252_row8_col5 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_5d252_row2_col12, #T_5d252_row4_col12, #T_5d252_row7_col12, #T_5d252_row8_col13, #T_5d252_row10_col8 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_5d252_row2_col13 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_5d252_row4_col13 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_5d252_row5_col0 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_5d252_row5_col8, #T_5d252_row9_col11 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_5d252_row5_col10, #T_5d252_row5_col12, #T_5d252_row5_col13, #T_5d252_row10_col13, #T_5d252_row13_col10 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_5d252_row6_col1, #T_5d252_row6_col3 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# #T_5d252_row6_col2 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_5d252_row6_col4 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_5d252_row6_col8, #T_5d252_row10_col12 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_5d252_row10_col0 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_5d252_row11_col0 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_5d252_row11_col5, #T_5d252_row13_col5 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_5d252_row11_col6 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_5d252_row11_col13, #T_5d252_row13_col11 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_5d252_row12_col5 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_5d252_row12_col13 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_5d252_row13_col0 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_5d252_row13_col1, #T_5d252_row13_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_5d252_row13_col2, #T_5d252_row13_col4 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_5d252_row13_col8 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# </style>
# <table id="T_5d252">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d252_level0_col0" class="col_heading level0 col0" >fare_amount</th>
#       <th id="T_5d252_level0_col1" class="col_heading level0 col1" >pickup_longitude</th>
#       <th id="T_5d252_level0_col2" class="col_heading level0 col2" >pickup_latitude</th>
#       <th id="T_5d252_level0_col3" class="col_heading level0 col3" >dropoff_longitude</th>
#       <th id="T_5d252_level0_col4" class="col_heading level0 col4" >dropoff_latitude</th>
#       <th id="T_5d252_level0_col5" class="col_heading level0 col5" >passenger_count</th>
#       <th id="T_5d252_level0_col6" class="col_heading level0 col6" >second</th>
#       <th id="T_5d252_level0_col7" class="col_heading level0 col7" >minute</th>
#       <th id="T_5d252_level0_col8" class="col_heading level0 col8" >hour</th>
#       <th id="T_5d252_level0_col9" class="col_heading level0 col9" >day</th>
#       <th id="T_5d252_level0_col10" class="col_heading level0 col10" >month</th>
#       <th id="T_5d252_level0_col11" class="col_heading level0 col11" >year</th>
#       <th id="T_5d252_level0_col12" class="col_heading level0 col12" >dayofweek</th>
#       <th id="T_5d252_level0_col13" class="col_heading level0 col13" >Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d252_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_5d252_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5d252_row0_col1" class="data row0 col1" >0.005885</td>
#       <td id="T_5d252_row0_col2" class="data row0 col2" >-0.006253</td>
#       <td id="T_5d252_row0_col3" class="data row0 col3" >0.005501</td>
#       <td id="T_5d252_row0_col4" class="data row0 col4" >-0.00

# %%
X = df['Distance'].values.reshape(-1, 1)        #Independent Variable
y = df['fare_amount'].values.reshape(-1, 1)     #Dependent Variable

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
y_std = std.fit_transform(y)
x_std = std.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = l_reg.predict(X_test)

result = pd.DataFrame()
result[['Actual']] = y_test
result[['Predicted']] = y_pred

result.sample(10)
# Out:
#          Actual  Predicted
# 9150  -0.606437  -0.455482
# 13076 -0.502323  -0.536918
# 37741  0.288946   0.290140
# 14967 -0.137922  -0.398419
# 7561  -0.252448  -0.187128
# 14594  0.663758  -0.698755
# 23595  4.789811   3.842606
# 33919  0.122363   0.376231
# 9339  -0.294094  -0.491625
# 21300 -0.793843  -0.630070

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred,squared=False))
print('R Squared (R²):', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.2662129875793894
# Mean Absolute % Error: 1.983074763340742
# Mean Squared Error: 0.27052435107785416
# Root Mean Squared Error: 0.5201195546005304
# R Squared (R²): 0.7340467931331909

# %%
rf_reg = RandomForestRegressor(n_estimators=100, random_state=10)

# fit the regressor with training dataset
rf_reg.fit(X_train, y_train)
# Out:
# C:\Users\Maddy\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# predict the values on test dataset using predict()
y_pred_RF = rf_reg.predict(X_test)

result = pd.DataFrame()
result[['Actual']] = y_test
result['Predicted'] = y_pred_RF

result.sample(10)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_RF))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred_RF))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_RF))
print('Root Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_RF))
print('R Squared (R²):', metrics.r2_score(y_test, y_pred_RF))
